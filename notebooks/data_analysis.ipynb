# %%
import numpy as np
from src.loader import Loader
from src.viewer import Viewer
from src.preprocessor import Preprocessor, DataType
from src.utils import ADMISSION_FEATURES

# %%
loader = Loader("data")
admission = loader.load()
viewer = Viewer(admission)

# %%
viewer.describe_feature("HTN")
# Out:
# nans: 0

# %%
Viewer(admission[admission["HTN"] == 1]).describe_feature("OUTCOME")
# Out:
# nans: 0

# %%
Viewer(admission[admission["AGE"] > 90]).describe_feature("EF")
# Out:
# nans: 5
